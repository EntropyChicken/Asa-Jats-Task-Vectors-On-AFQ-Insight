# %%
import torch; torch.manual_seed(0)
import torch.nn as nn
import torch.nn.functional as F
import torch.utils
import torch.distributions
import torchvision
import numpy as np
import matplotlib.pyplot as plt; plt.rcParams['figure.dpi'] = 200
from afqinsight import AFQDataset
from afqinsight.nn.utils import prep_pytorch_data
from afqinsight.nn.utils import vae_loss, kl_divergence_loss
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from torch.distributions.normal import Normal
from sklearn.decomposition import PCA
import afqinsight.augmentation as aug
import pandas as pd
import seaborn as sns
from afqinsight.nn.pt_models import VariationalAutoencoder

# %%
import sys 
sys.path.insert(1, '/Users/samchou/AFQ-Insight-Autoencoder-Experiments/AFQ-Insight-Autoencoder-Experiments/Experiment_Utils')
from utils import train_variational_autoencoder, select_device, prep_first_tract_data

# %%
# FIRST TRACT DATASET
# VARIATIONAL 
# CONVOLUTIONAL AUTOENCODER
# TESTING LATENT AND DROPOUT SIMULTATENTOUSLY

# %%
device = select_device()
# Out:
# Using device: mps
#
# Using MPS backend on macOS. (Detailed memory info may not be available.)

# %%
dataset = AFQDataset.from_study('hbn')
torch_dataset, train_loader, test_loader, val_loader = prep_pytorch_data(dataset,batch_size=64)  
gt_shape = torch_dataset[0][1].size()[0]
sequence_length = torch_dataset[0][0].size()[0]  # 48
in_channels = torch_dataset[0][0].size()[1]  # 100
# Out:
# File /Users/samchou/.cache/afq-insight/hbn/subjects.tsv exists.
# File /Users/samchou/.cache/afq-insight/hbn/nodes.csv exists.
# /Users/samchou/src/nrdg/AFQ-Insight/afqinsight/transform.py:144: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   features = interpolated.stack(["subjectID", "tractID", "metric"]).unstack(

# %%
torch_dataset, first_tract_train_loader, first_tract_test_loader, first_tract_val_loader = prep_first_tract_data(
    dataset, batch_size=64
)

# %%
latent_dims = [2, 4, 8, 16, 32, 64, 100]
dropout_values = [0.0, 0.1, 0.5]
models = {}
results = {}

for dropout in dropout_values:
    for latent_dim in latent_dims:
        print(f"Training Autoencoder with Latent Dimension: {latent_dim} and Dropout: {dropout}")
        
        # Initialize a new autoencoder for each latent dimension
        test_model = VariationalAutoencoder(input_shape= 100, latent_dims=latent_dim, dropout=dropout).to(device)
        
        # Train the model 
        training_results = train_variational_autoencoder(
            test_model,                    
            first_tract_train_loader,
            first_tract_val_loader,
            epochs=10,
            lr=1e-3,
            device=device,                  
            mixed_precision = (device.type == "cuda")
        )
        
        # Store both the model and results
        models[latent_dim, dropout] = test_model
        results[latent_dim, dropout] = training_results
        
        print(f"Completed training for latent_dim={latent_dim}, Best Val RMSE: {training_results['best_val_rmse']:.4f}")
# Out:
# Training Autoencoder with Latent Dimension: 2 and Dropout: 0.0
# Saving best model state with RMSE: 0.3186 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4430, Val RMSE: 0.3186, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 20.0971, Recon (Val): 10.1509
# Saving best model state with RMSE: 0.1341 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2280, Val RMSE: 0.1341, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 5.4902, Recon (Val): 1.7985
# Saving best model state with RMSE: 0.0572 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.0853, Val RMSE: 0.0572, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.7848, Recon (Val): 0.3271
# Saving best model state with RMSE: 0.0474 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0490, Val RMSE: 0.0474, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2420, Recon (Val): 0.2252
# Saving best model state with RMSE: 0.0447 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0435, Val RMSE: 0.0447, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1895, Recon (Val): 0.2003
# Saving best model state with RMSE: 0.0426 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0407, Val RMSE: 0.0426, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1659, Recon (Val): 0.1826
# Saving best model state with RMSE: 0.0414 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0395, Val RMSE: 0.0414, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1565, Recon (Val): 0.1721
# Saving best model state with RMSE: 0.0407 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0383, Val RMSE: 0.0407, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1473, Recon (Val): 0.1661
# Saving best model state with RMSE: 0.0393 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0374, Val RMSE: 0.0393, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1400, Recon (Val): 0.1553
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0369, Val RMSE: 0.0396, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1362, Recon (Val): 0.1572
# Training complete. Best model was from epoch 9 with validation RMSE: 0.0393
# Completed training for latent_dim=2, Best Val RMSE: 0.0393
# Training Autoencoder with Latent Dimension: 4 and Dropout: 0.0
# Saving best model state with RMSE: 0.3181 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4137, Val RMSE: 0.3181, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 17.3750, Recon (Val): 10.1187
# Saving best model state with RMSE: 0.1725 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2473, Val RMSE: 0.1725, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 6.3006, Recon (Val): 2.9772
# Saving best model state with RMSE: 0.0676 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1138, Val RMSE: 0.0676, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.4048, Recon (Val): 0.4577
# Saving best model state with RMSE: 0.0488 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0528, Val RMSE: 0.0488, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2827, Recon (Val): 0.2384
# Saving best model state with RMSE: 0.0448 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0435, Val RMSE: 0.0448, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1897, Recon (Val): 0.2012
# Saving best model state with RMSE: 0.0431 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0414, Val RMSE: 0.0431, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1716, Recon (Val): 0.1862
# Saving best model state with RMSE: 0.0428 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0404, Val RMSE: 0.0428, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1636, Recon (Val): 0.1837
# Saving best model state with RMSE: 0.0415 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0393, Val RMSE: 0.0415, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1546, Recon (Val): 0.1731
# Saving best model state with RMSE: 0.0400 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0384, Val RMSE: 0.0400, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1479, Recon (Val): 0.1608
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0380, Val RMSE: 0.0405, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1445, Recon (Val): 0.1641
# Training complete. Best model was from epoch 9 with validation RMSE: 0.0400
# Completed training for latent_dim=4, Best Val RMSE: 0.0400
# Training Autoencoder with Latent Dimension: 8 and Dropout: 0.0
# Saving best model state with RMSE: 0.3418 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4395, Val RMSE: 0.3418, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 19.5773, Recon (Val): 11.6834
# Saving best model state with RMSE: 0.1757 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2636, Val RMSE: 0.1757, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 7.1644, Recon (Val): 3.0887
# Saving best model state with RMSE: 0.0691 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1167, Val RMSE: 0.0691, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.4778, Recon (Val): 0.4781
# Saving best model state with RMSE: 0.0444 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0520, Val RMSE: 0.0444, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2762, Recon (Val): 0.1980
# Saving best model state with RMSE: 0.0408 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0400, Val RMSE: 0.0408, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1608, Recon (Val): 0.1669
# Saving best model state with RMSE: 0.0403 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0383, Val RMSE: 0.0403, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1466, Recon (Val): 0.1625
# Saving best model state with RMSE: 0.0398 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0377, Val RMSE: 0.0398, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1420, Recon (Val): 0.1590
# Saving best model state with RMSE: 0.0393 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0374, Val RMSE: 0.0393, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1402, Recon (Val): 0.1552
# Saving best model state with RMSE: 0.0389 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0369, Val RMSE: 0.0389, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1366, Recon (Val): 0.1519
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0368, Val RMSE: 0.0391, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1354, Recon (Val): 0.1534
# Training complete. Best model was from epoch 9 with validation RMSE: 0.0389
# Completed training for latent_dim=8, Best Val RMSE: 0.0389
# Training Autoencoder with Latent Dimension: 16 and Dropout: 0.0
# Saving best model state with RMSE: 0.3029 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4180, Val RMSE: 0.3029, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 17.8391, Recon (Val): 9.1763
# Saving best model state with RMSE: 0.1448 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2204, Val RMSE: 0.1448, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 5.0863, Recon (Val): 2.0980
# Saving best model state with RMSE: 0.0688 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1023, Val RMSE: 0.0688, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.0993, Recon (Val): 0.4748
# Saving best model state with RMSE: 0.0478 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0541, Val RMSE: 0.0478, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2970, Recon (Val): 0.2293
# Saving best model state with RMSE: 0.0432 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0425, Val RMSE: 0.0432, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1812, Recon (Val): 0.1876
# Saving best model state with RMSE: 0.0414 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0399, Val RMSE: 0.0414, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1596, Recon (Val): 0.1723
# Saving best model state with RMSE: 0.0409 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0387, Val RMSE: 0.0409, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1501, Recon (Val): 0.1679
# Saving best model state with RMSE: 0.0408 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0386, Val RMSE: 0.0408, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1491, Recon (Val): 0.1668
# Saving best model state with RMSE: 0.0404 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0380, Val RMSE: 0.0404, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1445, Recon (Val): 0.1636
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0377, Val RMSE: 0.0404, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1426, Recon (Val): 0.1639
# Training complete. Best model was from epoch 9 with validation RMSE: 0.0404
# Completed training for latent_dim=16, Best Val RMSE: 0.0404
# Training Autoencoder with Latent Dimension: 32 and Dropout: 0.0
# Saving best model state with RMSE: 0.3224 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4440, Val RMSE: 0.3224, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 20.1233, Recon (Val): 10.3917
# Saving best model state with RMSE: 0.1632 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2384, Val RMSE: 0.1632, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 5.8924, Recon (Val): 2.6624
# Saving best model state with RMSE: 0.0748 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1161, Val RMSE: 0.0748, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.4134, Recon (Val): 0.5593
# Saving best model state with RMSE: 0.0475 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0574, Val RMSE: 0.0475, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3374, Recon (Val): 0.2260
# Saving best model state with RMSE: 0.0422 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0424, Val RMSE: 0.0422, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1801, Recon (Val): 0.1783
# Saving best model state with RMSE: 0.0410 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0393, Val RMSE: 0.0410, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1548, Recon (Val): 0.1685
# Saving best model state with RMSE: 0.0402 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0382, Val RMSE: 0.0402, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1464, Recon (Val): 0.1620
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0378, Val RMSE: 0.0403, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1429, Recon (Val): 0.1629
# Saving best model state with RMSE: 0.0394 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0378, Val RMSE: 0.0394, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1431, Recon (Val): 0.1561
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0374, Val RMSE: 0.0396, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1401, Recon (Val): 0.1571
# Training complete. Best model was from epoch 9 with validation RMSE: 0.0394
# Completed training for latent_dim=32, Best Val RMSE: 0.0394
# Training Autoencoder with Latent Dimension: 64 and Dropout: 0.0
# Saving best model state with RMSE: 0.2941 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4182, Val RMSE: 0.2941, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 17.8958, Recon (Val): 8.6482
# Saving best model state with RMSE: 0.1514 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2226, Val RMSE: 0.1514, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 5.1493, Recon (Val): 2.2924
# Saving best model state with RMSE: 0.0728 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1091, Val RMSE: 0.0728, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.2444, Recon (Val): 0.5298
# Saving best model state with RMSE: 0.0501 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0595, Val RMSE: 0.0501, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3584, Recon (Val): 0.2518
# Saving best model state with RMSE: 0.0439 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0443, Val RMSE: 0.0439, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1966, Recon (Val): 0.1931
# Saving best model state with RMSE: 0.0411 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0402, Val RMSE: 0.0411, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1621, Recon (Val): 0.1693
# Saving best model state with RMSE: 0.0405 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0387, Val RMSE: 0.0405, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1498, Recon (Val): 0.1648
# Saving best model state with RMSE: 0.0402 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0381, Val RMSE: 0.0402, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1451, Recon (Val): 0.1621
# Saving best model state with RMSE: 0.0399 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0376, Val RMSE: 0.0399, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1415, Recon (Val): 0.1594
# Saving best model state with RMSE: 0.0396 at epoch 10
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0375, Val RMSE: 0.0396, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1407, Recon (Val): 0.1574
# Training complete. Best model was from epoch 10 with validation RMSE: 0.0396
# Completed training for latent_dim=64, Best Val RMSE: 0.0396
# Training Autoencoder with Latent Dimension: 100 and Dropout: 0.0
# Saving best model state with RMSE: 0.2834 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4109, Val RMSE: 0.2834, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 17.4296, Recon (Val): 8.0338
# Saving best model state with RMSE: 0.1299 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.1988, Val RMSE: 0.1299, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 4.1585, Recon (Val): 1.6870
# Saving best model state with RMSE: 0.0688 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.0971, Val RMSE: 0.0688, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.9770, Recon (Val): 0.4733
# Saving best model state with RMSE: 0.0483 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0553, Val RMSE: 0.0483, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3097, Recon (Val): 0.2339
# Saving best model state with RMSE: 0.0435 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0432, Val RMSE: 0.0435, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1874, Recon (Val): 0.1895
# Saving best model state with RMSE: 0.0416 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0402, Val RMSE: 0.0416, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1621, Recon (Val): 0.1734
# Saving best model state with RMSE: 0.0407 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0391, Val RMSE: 0.0407, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1527, Recon (Val): 0.1662
# Saving best model state with RMSE: 0.0403 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0384, Val RMSE: 0.0403, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1481, Recon (Val): 0.1632
# Saving best model state with RMSE: 0.0400 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0382, Val RMSE: 0.0400, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1464, Recon (Val): 0.1602
# Saving best model state with RMSE: 0.0397 at epoch 10
# Best model saved to: best_vae_model_ldunknown_dr0.0.pth
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0379, Val RMSE: 0.0397, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.1437, Recon (Val): 0.1584
# Training complete. Best model was from epoch 10 with validation RMSE: 0.0397
# Completed training for latent_dim=100, Best Val RMSE: 0.0397
# Training Autoencoder with Latent Dimension: 2 and Dropout: 0.1
# Saving best model state with RMSE: 0.3359 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4486, Val RMSE: 0.3359, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 20.5253, Recon (Val): 11.2828
# Saving best model state with RMSE: 0.1633 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2560, Val RMSE: 0.1633, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 6.7897, Recon (Val): 2.6681
# Saving best model state with RMSE: 0.0642 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1153, Val RMSE: 0.0642, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.4018, Recon (Val): 0.4128
# Saving best model state with RMSE: 0.0484 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0646, Val RMSE: 0.0484, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.4203, Recon (Val): 0.2348
# Saving best model state with RMSE: 0.0455 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0529, Val RMSE: 0.0455, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2826, Recon (Val): 0.2079
# Saving best model state with RMSE: 0.0443 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0483, Val RMSE: 0.0443, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2344, Recon (Val): 0.1973
# Saving best model state with RMSE: 0.0440 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0469, Val RMSE: 0.0440, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2202, Recon (Val): 0.1940
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0468, Val RMSE: 0.0445, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2195, Recon (Val): 0.1982
# Saving best model state with RMSE: 0.0437 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0453, Val RMSE: 0.0437, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2060, Recon (Val): 0.1917
# Saving best model state with RMSE: 0.0434 at epoch 10
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0449, Val RMSE: 0.0434, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2017, Recon (Val): 0.1894
# Training complete. Best model was from epoch 10 with validation RMSE: 0.0434
# Completed training for latent_dim=2, Best Val RMSE: 0.0434
# Training Autoencoder with Latent Dimension: 4 and Dropout: 0.1
# Saving best model state with RMSE: 0.2829 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4050, Val RMSE: 0.2829, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 16.8875, Recon (Val): 8.0034
# Saving best model state with RMSE: 0.1093 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.1978, Val RMSE: 0.1093, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 4.1620, Recon (Val): 1.1961
# Saving best model state with RMSE: 0.0590 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.0868, Val RMSE: 0.0590, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.7774, Recon (Val): 0.3494
# Saving best model state with RMSE: 0.0460 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0619, Val RMSE: 0.0460, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3854, Recon (Val): 0.2116
# Saving best model state with RMSE: 0.0448 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0535, Val RMSE: 0.0448, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2869, Recon (Val): 0.2011
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0513, Val RMSE: 0.0475, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2634, Recon (Val): 0.2259
# Saving best model state with RMSE: 0.0442 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0487, Val RMSE: 0.0442, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2373, Recon (Val): 0.1957
# Saving best model state with RMSE: 0.0439 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0468, Val RMSE: 0.0439, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2197, Recon (Val): 0.1930
# Saving best model state with RMSE: 0.0431 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0454, Val RMSE: 0.0431, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2064, Recon (Val): 0.1861
# Saving best model state with RMSE: 0.0426 at epoch 10
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0452, Val RMSE: 0.0426, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2046, Recon (Val): 0.1815
# Training complete. Best model was from epoch 10 with validation RMSE: 0.0426
# Completed training for latent_dim=4, Best Val RMSE: 0.0426
# Training Autoencoder with Latent Dimension: 8 and Dropout: 0.1
# Saving best model state with RMSE: 0.3310 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4471, Val RMSE: 0.3310, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 20.3878, Recon (Val): 10.9549
# Saving best model state with RMSE: 0.1687 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2497, Val RMSE: 0.1687, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 6.4725, Recon (Val): 2.8456
# Saving best model state with RMSE: 0.0828 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1268, Val RMSE: 0.0828, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.6677, Recon (Val): 0.6864
# Saving best model state with RMSE: 0.0510 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0763, Val RMSE: 0.0510, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.5899, Recon (Val): 0.2603
# Saving best model state with RMSE: 0.0455 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0598, Val RMSE: 0.0455, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3586, Recon (Val): 0.2078
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0537, Val RMSE: 0.0482, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2891, Recon (Val): 0.2328
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0510, Val RMSE: 0.0462, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2602, Recon (Val): 0.2139
# Saving best model state with RMSE: 0.0431 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0493, Val RMSE: 0.0431, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2437, Recon (Val): 0.1859
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0488, Val RMSE: 0.0491, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2387, Recon (Val): 0.2416
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0470, Val RMSE: 0.0496, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2219, Recon (Val): 0.2459
# Training complete. Best model was from epoch 8 with validation RMSE: 0.0431
# Completed training for latent_dim=8, Best Val RMSE: 0.0431
# Training Autoencoder with Latent Dimension: 16 and Dropout: 0.1
# Saving best model state with RMSE: 0.3095 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4279, Val RMSE: 0.3095, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 18.7056, Recon (Val): 9.5821
# Saving best model state with RMSE: 0.1467 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2287, Val RMSE: 0.1467, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 5.4526, Recon (Val): 2.1517
# Saving best model state with RMSE: 0.0702 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1139, Val RMSE: 0.0702, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.3372, Recon (Val): 0.4933
# Saving best model state with RMSE: 0.0490 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0719, Val RMSE: 0.0490, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.5200, Recon (Val): 0.2406
# Saving best model state with RMSE: 0.0489 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0613, Val RMSE: 0.0489, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3767, Recon (Val): 0.2392
# Saving best model state with RMSE: 0.0454 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0534, Val RMSE: 0.0454, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2850, Recon (Val): 0.2062
# Saving best model state with RMSE: 0.0443 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0506, Val RMSE: 0.0443, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2565, Recon (Val): 0.1964
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0491, Val RMSE: 0.0462, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2416, Recon (Val): 0.2141
# Saving best model state with RMSE: 0.0433 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0478, Val RMSE: 0.0433, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2293, Recon (Val): 0.1882
# Saving best model state with RMSE: 0.0425 at epoch 10
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0465, Val RMSE: 0.0425, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2167, Recon (Val): 0.1810
# Training complete. Best model was from epoch 10 with validation RMSE: 0.0425
# Completed training for latent_dim=16, Best Val RMSE: 0.0425
# Training Autoencoder with Latent Dimension: 32 and Dropout: 0.1
# Saving best model state with RMSE: 0.2748 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4037, Val RMSE: 0.2748, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 16.7941, Recon (Val): 7.5566
# Saving best model state with RMSE: 0.1311 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2045, Val RMSE: 0.1311, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 4.3560, Recon (Val): 1.7178
# Saving best model state with RMSE: 0.0628 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.0983, Val RMSE: 0.0628, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.0038, Recon (Val): 0.3946
# Saving best model state with RMSE: 0.0455 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0635, Val RMSE: 0.0455, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.4051, Recon (Val): 0.2078
# Saving best model state with RMSE: 0.0440 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0564, Val RMSE: 0.0440, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3183, Recon (Val): 0.1938
# Saving best model state with RMSE: 0.0428 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0527, Val RMSE: 0.0428, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2780, Recon (Val): 0.1833
# Saving best model state with RMSE: 0.0421 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0503, Val RMSE: 0.0421, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2533, Recon (Val): 0.1778
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0484, Val RMSE: 0.0446, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2345, Recon (Val): 0.1998
# Saving best model state with RMSE: 0.0414 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0468, Val RMSE: 0.0414, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2196, Recon (Val): 0.1721
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0469, Val RMSE: 0.0431, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2199, Recon (Val): 0.1865
# Training complete. Best model was from epoch 9 with validation RMSE: 0.0414
# Completed training for latent_dim=32, Best Val RMSE: 0.0414
# Training Autoencoder with Latent Dimension: 64 and Dropout: 0.1
# Saving best model state with RMSE: 0.2895 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4189, Val RMSE: 0.2895, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 18.0610, Recon (Val): 8.3853
# Saving best model state with RMSE: 0.1304 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2117, Val RMSE: 0.1304, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 4.6945, Recon (Val): 1.7013
# Saving best model state with RMSE: 0.0674 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1032, Val RMSE: 0.0674, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.1021, Recon (Val): 0.4549
# Saving best model state with RMSE: 0.0464 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0660, Val RMSE: 0.0464, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.4396, Recon (Val): 0.2156
# Saving best model state with RMSE: 0.0434 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0565, Val RMSE: 0.0434, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3205, Recon (Val): 0.1891
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0527, Val RMSE: 0.0454, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2784, Recon (Val): 0.2063
# Saving best model state with RMSE: 0.0422 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0505, Val RMSE: 0.0422, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2553, Recon (Val): 0.1782
# Saving best model state with RMSE: 0.0411 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0492, Val RMSE: 0.0411, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2422, Recon (Val): 0.1693
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0494, Val RMSE: 0.0432, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2448, Recon (Val): 0.1873
# Saving best model state with RMSE: 0.0410 at epoch 10
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0467, Val RMSE: 0.0410, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2183, Recon (Val): 0.1689
# Training complete. Best model was from epoch 10 with validation RMSE: 0.0410
# Completed training for latent_dim=64, Best Val RMSE: 0.0410
# Training Autoencoder with Latent Dimension: 100 and Dropout: 0.1
# Saving best model state with RMSE: 0.2895 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4178, Val RMSE: 0.2895, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 17.9741, Recon (Val): 8.3851
# Saving best model state with RMSE: 0.1581 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2249, Val RMSE: 0.1581, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 5.2020, Recon (Val): 2.5009
# Saving best model state with RMSE: 0.0807 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1258, Val RMSE: 0.0807, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.6288, Recon (Val): 0.6521
# Saving best model state with RMSE: 0.0524 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.0753, Val RMSE: 0.0524, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.5747, Recon (Val): 0.2751
# Saving best model state with RMSE: 0.0481 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0610, Val RMSE: 0.0481, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3725, Recon (Val): 0.2321
# Saving best model state with RMSE: 0.0451 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0572, Val RMSE: 0.0451, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3276, Recon (Val): 0.2034
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0544, Val RMSE: 0.0461, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2971, Recon (Val): 0.2126
# Saving best model state with RMSE: 0.0433 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.1.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0519, Val RMSE: 0.0433, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2700, Recon (Val): 0.1882
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0501, Val RMSE: 0.0443, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2515, Recon (Val): 0.1965
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0483, Val RMSE: 0.0482, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2341, Recon (Val): 0.2323
# Training complete. Best model was from epoch 8 with validation RMSE: 0.0433
# Completed training for latent_dim=100, Best Val RMSE: 0.0433
# Training Autoencoder with Latent Dimension: 2 and Dropout: 0.5
# Saving best model state with RMSE: 0.3126 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4271, Val RMSE: 0.3126, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 18.5949, Recon (Val): 9.7757
# Saving best model state with RMSE: 0.1426 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2413, Val RMSE: 0.1426, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 6.0291, Recon (Val): 2.0364
# Saving best model state with RMSE: 0.0753 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1429, Val RMSE: 0.0753, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 2.0890, Recon (Val): 0.5671
# Saving best model state with RMSE: 0.0599 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.1003, Val RMSE: 0.0599, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.0141, Recon (Val): 0.3594
# Saving best model state with RMSE: 0.0541 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0758, Val RMSE: 0.0541, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.5782, Recon (Val): 0.2931
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0605, Val RMSE: 0.0551, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3687, Recon (Val): 0.3041
# Saving best model state with RMSE: 0.0539 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0550, Val RMSE: 0.0539, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3039, Recon (Val): 0.2910
# Saving best model state with RMSE: 0.0538 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0528, Val RMSE: 0.0538, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2799, Recon (Val): 0.2895
# Saving best model state with RMSE: 0.0530 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0520, Val RMSE: 0.0530, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2711, Recon (Val): 0.2810
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0516, Val RMSE: 0.0531, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2670, Recon (Val): 0.2825
# Training complete. Best model was from epoch 9 with validation RMSE: 0.0530
# Completed training for latent_dim=2, Best Val RMSE: 0.0530
# Training Autoencoder with Latent Dimension: 4 and Dropout: 0.5
# Saving best model state with RMSE: 0.3453 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4435, Val RMSE: 0.3453, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 19.9836, Recon (Val): 11.9247
# Saving best model state with RMSE: 0.1789 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2676, Val RMSE: 0.1789, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 7.3499, Recon (Val): 3.2041
# Saving best model state with RMSE: 0.0984 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1507, Val RMSE: 0.0984, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 2.3231, Recon (Val): 0.9687
# Saving best model state with RMSE: 0.0758 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.1053, Val RMSE: 0.0758, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.1137, Recon (Val): 0.5747
# Saving best model state with RMSE: 0.0612 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0832, Val RMSE: 0.0612, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.6963, Recon (Val): 0.3744
# Saving best model state with RMSE: 0.0575 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0679, Val RMSE: 0.0575, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.4630, Recon (Val): 0.3318
# Saving best model state with RMSE: 0.0515 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0598, Val RMSE: 0.0515, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3586, Recon (Val): 0.2652
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0554, Val RMSE: 0.0539, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3084, Recon (Val): 0.2914
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0527, Val RMSE: 0.0515, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2781, Recon (Val): 0.2659
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0524, Val RMSE: 0.0524, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2756, Recon (Val): 0.2750
# Training complete. Best model was from epoch 7 with validation RMSE: 0.0515
# Completed training for latent_dim=4, Best Val RMSE: 0.0515
# Training Autoencoder with Latent Dimension: 8 and Dropout: 0.5
# Saving best model state with RMSE: 0.3362 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4464, Val RMSE: 0.3362, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 20.2939, Recon (Val): 11.3062
# Saving best model state with RMSE: 0.1768 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2607, Val RMSE: 0.1768, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 6.9999, Recon (Val): 3.1278
# Saving best model state with RMSE: 0.0993 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1548, Val RMSE: 0.0993, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 2.4294, Recon (Val): 0.9870
# Saving best model state with RMSE: 0.0812 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.1093, Val RMSE: 0.0812, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.2035, Recon (Val): 0.6595
# Saving best model state with RMSE: 0.0678 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0870, Val RMSE: 0.0678, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.7630, Recon (Val): 0.4604
# Saving best model state with RMSE: 0.0618 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0731, Val RMSE: 0.0618, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.5358, Recon (Val): 0.3819
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0627, Val RMSE: 0.0640, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3952, Recon (Val): 0.4096
# Saving best model state with RMSE: 0.0567 at epoch 8
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0583, Val RMSE: 0.0567, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3407, Recon (Val): 0.3217
# Saving best model state with RMSE: 0.0536 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0547, Val RMSE: 0.0536, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3000, Recon (Val): 0.2881
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0526, Val RMSE: 0.0554, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.2776, Recon (Val): 0.3078
# Training complete. Best model was from epoch 9 with validation RMSE: 0.0536
# Completed training for latent_dim=8, Best Val RMSE: 0.0536
# Training Autoencoder with Latent Dimension: 16 and Dropout: 0.5
# Saving best model state with RMSE: 0.3029 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4298, Val RMSE: 0.3029, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 18.8776, Recon (Val): 9.1748
# Saving best model state with RMSE: 0.1458 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2320, Val RMSE: 0.1458, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 5.5687, Recon (Val): 2.1266
# Saving best model state with RMSE: 0.0851 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1413, Val RMSE: 0.0851, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 2.0241, Recon (Val): 0.7250
# Saving best model state with RMSE: 0.0688 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.1043, Val RMSE: 0.0688, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.0930, Recon (Val): 0.4733
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0924, Val RMSE: 0.0726, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.8583, Recon (Val): 0.5265
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0796, Val RMSE: 0.0723, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.6346, Recon (Val): 0.5234
# Saving best model state with RMSE: 0.0543 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0724, Val RMSE: 0.0543, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.5257, Recon (Val): 0.2950
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0680, Val RMSE: 0.0706, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.4633, Recon (Val): 0.4992
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0619, Val RMSE: 0.0566, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3838, Recon (Val): 0.3211
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0601, Val RMSE: 0.0615, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3628, Recon (Val): 0.3784
# Training complete. Best model was from epoch 7 with validation RMSE: 0.0543
# Completed training for latent_dim=16, Best Val RMSE: 0.0543
# Training Autoencoder with Latent Dimension: 32 and Dropout: 0.5
# Saving best model state with RMSE: 0.3025 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4233, Val RMSE: 0.3025, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 18.3250, Recon (Val): 9.1556
# Saving best model state with RMSE: 0.1702 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2394, Val RMSE: 0.1702, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 5.8713, Recon (Val): 2.8972
# Saving best model state with RMSE: 0.1010 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1514, Val RMSE: 0.1010, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 2.3232, Recon (Val): 1.0203
# Saving best model state with RMSE: 0.0841 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.1100, Val RMSE: 0.0841, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.2214, Recon (Val): 0.7080
# Saving best model state with RMSE: 0.0771 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0902, Val RMSE: 0.0771, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.8164, Recon (Val): 0.5951
# Saving best model state with RMSE: 0.0704 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0780, Val RMSE: 0.0704, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.6104, Recon (Val): 0.4959
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0735, Val RMSE: 0.0731, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.5410, Recon (Val): 0.5344
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0685, Val RMSE: 0.0750, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.4708, Recon (Val): 0.5649
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0636, Val RMSE: 0.0760, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.4054, Recon (Val): 0.5792
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0617, Val RMSE: 0.0737, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.3828, Recon (Val): 0.5436
# Training complete. Best model was from epoch 6 with validation RMSE: 0.0704
# Completed training for latent_dim=32, Best Val RMSE: 0.0704
# Training Autoencoder with Latent Dimension: 64 and Dropout: 0.5
# Saving best model state with RMSE: 0.2981 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4209, Val RMSE: 0.2981, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 18.1550, Recon (Val): 8.8886
# Saving best model state with RMSE: 0.1766 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2399, Val RMSE: 0.1766, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 5.8785, Recon (Val): 3.1195
# Saving best model state with RMSE: 0.1212 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1583, Val RMSE: 0.1212, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 2.5310, Recon (Val): 1.4705
# Saving best model state with RMSE: 0.0855 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.1166, Val RMSE: 0.0855, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.3668, Recon (Val): 0.7318
# Saving best model state with RMSE: 0.0739 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0936, Val RMSE: 0.0739, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.8805, Recon (Val): 0.5464
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0820, Val RMSE: 0.0746, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.6739, Recon (Val): 0.5574
# Saving best model state with RMSE: 0.0659 at epoch 7
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0743, Val RMSE: 0.0659, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.5533, Recon (Val): 0.4349
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0707, Val RMSE: 0.0697, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.5015, Recon (Val): 0.4854
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0651, Val RMSE: 0.0704, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.4240, Recon (Val): 0.4966
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0634, Val RMSE: 0.0673, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.4024, Recon (Val): 0.4536
# Training complete. Best model was from epoch 7 with validation RMSE: 0.0659
# Completed training for latent_dim=64, Best Val RMSE: 0.0659
# Training Autoencoder with Latent Dimension: 100 and Dropout: 0.5
# Saving best model state with RMSE: 0.2911 at epoch 1
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 1, KL Weight: 0.000000, Train RMSE: 0.4124, Val RMSE: 0.2911, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 17.4278, Recon (Val): 8.4741
# Saving best model state with RMSE: 0.1555 at epoch 2
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 2, KL Weight: 0.000000, Train RMSE: 0.2335, Val RMSE: 0.1555, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 5.6072, Recon (Val): 2.4192
# Saving best model state with RMSE: 0.0837 at epoch 3
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 3, KL Weight: 0.000000, Train RMSE: 0.1392, Val RMSE: 0.0837, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.9639, Recon (Val): 0.7009
# Saving best model state with RMSE: 0.0638 at epoch 4
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 4, KL Weight: 0.000000, Train RMSE: 0.1026, Val RMSE: 0.0638, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 1.0628, Recon (Val): 0.4073
# Saving best model state with RMSE: 0.0555 at epoch 5
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 5, KL Weight: 0.000000, Train RMSE: 0.0907, Val RMSE: 0.0555, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.8241, Recon (Val): 0.3086
# Saving best model state with RMSE: 0.0522 at epoch 6
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 6, KL Weight: 0.000000, Train RMSE: 0.0804, Val RMSE: 0.0522, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.6504, Recon (Val): 0.2724
# Epoch 7, KL Weight: 0.000000, Train RMSE: 0.0748, Val RMSE: 0.0658, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.5628, Recon (Val): 0.4337
# Epoch 8, KL Weight: 0.000000, Train RMSE: 0.0728, Val RMSE: 0.0590, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.5327, Recon (Val): 0.3488
# Saving best model state with RMSE: 0.0496 at epoch 9
# Best model saved to: best_vae_model_ldunknown_dr0.5.pth
# Epoch 9, KL Weight: 0.000000, Train RMSE: 0.0681, Val RMSE: 0.0496, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.4655, Recon (Val): 0.2465
# Epoch 10, KL Weight: 0.000000, Train RMSE: 0.0655, Val RMSE: 0.0609, KL (Train): 0.0000, KL (Val): 0.0000, Recon (Train): 0.4302, Recon (Val): 0.3716
# Training complete. Best model was from epoch 9 with validation RMSE: 0.0496
# Completed training for latent_dim=100, Best Val RMSE: 0.0496

# %%
# Create a DataFrame with rows for dropout and columns for latent_dims
latent_dims = [2, 4, 8, 16, 32, 64, 100]
dropout_values = [0.0, 0.1, 0.5]
df_best_val = pd.DataFrame(index=dropout_values, columns=latent_dims)

# Populate the DataFrame with the best validation RMSE values
for latent_dim in latent_dims:
    for dropout in dropout_values:
        print(f"Latent Dim: {latent_dim}, Dropout: {dropout}")  
        key = (latent_dim, dropout)
        if key in results:
            best_val_loss = results[key]["best_val_rmse"]
            df_best_val.loc[dropout, latent_dim] = best_val_loss
        else:
            print(f"Key {key} not found in results.")
            # Handle missing key, e.g., set a default value
            df_best_val.loc[dropout, latent_dim] = np.nan  # or any other default


# Convert the values to floats (if they aren't already)
df_best_val = df_best_val.astype(float)

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df_best_val, annot=True, fmt=".3f", cmap="viridis")
plt.xlabel("Latent Dimensions")
plt.ylabel("Dropout Rate")
plt.title("Best Validation RMSE for Each Dropout and Latent Dimension Combination")
plt.show()
# Out:
# Latent Dim: 2, Dropout: 0.0
# Latent Dim: 2, Dropout: 0.1
# Latent Dim: 2, Dropout: 0.5
# Latent Dim: 4, Dropout: 0.0
# Latent Dim: 4, Dropout: 0.1
# Latent Dim: 4, Dropout: 0.5
# Latent Dim: 8, Dropout: 0.0
# Latent Dim: 8, Dropout: 0.1
# Latent Dim: 8, Dropout: 0.5
# Latent Dim: 16, Dropout: 0.0
# Latent Dim: 16, Dropout: 0.1
# Latent Dim: 16, Dropout: 0.5
# Latent Dim: 32, Dropout: 0.0
# Latent Dim: 32, Dropout: 0.1
# Latent Dim: 32, Dropout: 0.5
# Latent Dim: 64, Dropout: 0.0
# Latent Dim: 64, Dropout: 0.1
# Latent Dim: 64, Dropout: 0.5
# Latent Dim: 100, Dropout: 0.0
# Latent Dim: 100, Dropout: 0.1
# Latent Dim: 100, Dropout: 0.5

# %%
#selecting the model with 64 latent dimensions, 0.1 dropout
sample = first_tract_test_loader.dataset[0][0][0:1].unsqueeze(0).to(device)
output = models[16, 0.1](sample)

# Assuming the first element of the tuple is the reconstruction:
reconstructed = output[0]

orig = sample.cpu().detach().numpy()
recon = reconstructed.cpu().detach().numpy()

plt.plot(orig.flatten()[0:100], color='blue', label='Original')
plt.plot(recon.flatten()[0:100], color='red', label='Reconstructed')
